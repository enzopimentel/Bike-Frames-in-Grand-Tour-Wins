# %% [markdown]
# ### import libraries

# %%
import pandas as pd
import numpy as np
from datetime import timedelta

# %% [markdown]
# ### TDF 2022

# %%
TDF_22 = pd.read_excel(r'D:\enzo\Documents\Data Science\Bike Prices\TDF2022\TDF 2022 timecleaned.xlsx')
TDF_22
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 TDF_22 = pd.read_excel(r'D:\enzo\Documents\Data Science\Bike Prices\TDF2022\TDF 2022 timecleaned.xlsx')
#       2 TDF_22
#
# File c:\Users\enzo\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\util\_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File c:\Users\enzo\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\util\_decorators.py:317, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     311 if len(args) > num_allow_args:
#     312     warnings.warn(
#     313         msg.format(arguments=arguments),
#     314         FutureWarning,
# ...

# %%
TDF_22['Time'] = pd.to_timedelta(TDF_22['Time'])
TDF_22
# Out:
#      Unnamed: 0.1  Unnamed: 0  Pos  Unnamed: 1  Unnamed: 2  \
# 0               0           0    1         NaN         NaN
# 1               1           1    2         NaN         NaN
# 2               2           2    3         NaN         NaN
# 3               3           3    4         NaN         NaN
# 4               4           4    5         NaN         NaN
# ..            ...         ...  ...         ...         ...
# 171           171         171  DNF         NaN         NaN
# 172           172         172  DNF         NaN         NaN
# 173           173         173  DNF         NaN         NaN
# 174           174         174  DNF         NaN         NaN
# 175           175         175  DNF         NaN         NaN
#
#                     Rider               Team     UCI            Time  \
# 0        Vingegaard Jonas        Jumbo-Visma  1000.0 3 days 07:33:20
# 1           Pogacar Tadej  UAE Team Emirates   800.0 0 days 00:02:43
# ...

# %%
TDF_22['Time'].loc[1:] = TDF_22['Time'][0] + (TDF_22['Time'][1:])
TDF_22['Time']
# Out:
# C:\Users\enzo\AppData\Local\Temp\ipykernel_1704\4158184446.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   TDF_22['Time'].loc[1:] = TDF_22['Time'][0] + (TDF_22['Time'][1:])
# 0     3 days 07:33:20
# 1     3 days 07:36:03
# 2     3 days 07:40:42
# 3     3 days 07:46:59
# 4     3 days 07:49:06
#             ...
# 171               NaT
# 172               NaT
# 173               NaT
# 174               NaT
# 175               NaT
# Name: Time, Length: 176, dtype: timedelta64[ns]

# %%
TDF_22['duration_mins'] = (TDF_22['Time'].dt.total_seconds()/60).round(2)
TDF_22['duration_mins']
# Out:
# 0      4773.33
# 1      4776.05
# 2      4780.70
# 3      4786.98
# 4      4789.10
#         ...
# 171        NaN
# 172        NaN
# 173        NaN
# 174        NaN
# 175        NaN
# Name: duration_mins, Length: 176, dtype: float64

# %%
TDF_22
# Out:
#      Unnamed: 0.1  Unnamed: 0  Pos  Unnamed: 1  Unnamed: 2  \
# 0               0           0    1         NaN         NaN
# 1               1           1    2         NaN         NaN
# 2               2           2    3         NaN         NaN
# 3               3           3    4         NaN         NaN
# 4               4           4    5         NaN         NaN
# ..            ...         ...  ...         ...         ...
# 171           171         171  DNF         NaN         NaN
# 172           172         172  DNF         NaN         NaN
# 173           173         173  DNF         NaN         NaN
# 174           174         174  DNF         NaN         NaN
# 175           175         175  DNF         NaN         NaN
#
#                     Rider               Team     UCI            Time  \
# 0        Vingegaard Jonas        Jumbo-Visma  1000.0 3 days 07:33:20
# 1           Pogacar Tadej  UAE Team Emirates   800.0 3 days 07:36:03
# ...

# %%
TDF_22team = pd.read_excel(r'D:\enzo\Documents\Data Science\Bike Prices\TDF2022\TDF 2022 Team Time_cleaned.xlsx')
TDF_22team.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0  Pos  Unnamed: 1              Team       Time  \
# 0             0           0    1         NaN  INEOS Grenadiers  239:03:03
# 1             1           1    2         NaN      Groupama-FDJ   00:37:33
# 2             2           2    3         NaN       Jumbo-Visma   00:44:54
# 3             3           3    4         NaN    BORA-hansgrohe   01:48:45
# 4             4           4    5         NaN     Movistar Team   02:11:22
#
#    Unnamed: 6           Unnamed: 7  Unnamed: 8  Unnamed: 9 Unnamed: 10  \
# 0         NaN            239:03:03         NaN         NaN         NaN
# 1         NaN  1900-01-09 23:40:36         NaN         NaN         NaN
# 2         NaN  1900-01-09 23:47:57         NaN         NaN    00:44:54
# 3         NaN                  NaN         NaN         NaN    01:48:45
# 4         NaN                  NaN         NaN         NaN    02:11:22
#
#   Unnamed: 11  Unnamed: 12          Unnamed: 13  Unnamed: 14 Unnamed: 15  \
# ...

# %%
TDF_22team['Time'] = pd.to_timedelta(TDF_22team['Time'])
TDF_22team.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0  Pos  Unnamed: 1              Team  \
# 0             0           0    1         NaN  INEOS Grenadiers
# 1             1           1    2         NaN      Groupama-FDJ
# 2             2           2    3         NaN       Jumbo-Visma
# 3             3           3    4         NaN    BORA-hansgrohe
# 4             4           4    5         NaN     Movistar Team
#
#              Time  Unnamed: 6           Unnamed: 7  Unnamed: 8  Unnamed: 9  \
# 0 9 days 23:03:03         NaN            239:03:03         NaN         NaN
# 1 0 days 00:37:33         NaN  1900-01-09 23:40:36         NaN         NaN
# 2 0 days 00:44:54         NaN  1900-01-09 23:47:57         NaN         NaN
# 3 0 days 01:48:45         NaN                  NaN         NaN         NaN
# 4 0 days 02:11:22         NaN                  NaN         NaN         NaN
#
#   Unnamed: 10 Unnamed: 11  Unnamed: 12          Unnamed: 13  Unnamed: 14  \
# ...

# %%
TDF_22team['Time'].loc[1:] = TDF_22team['Time'][0] + (TDF_22team['Time'][1:])
TDF_22team['Time']
# Out:
# C:\Users\enzo\AppData\Local\Temp\ipykernel_1704\4051516224.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   TDF_22team['Time'].loc[1:] = TDF_22team['Time'][0] + (TDF_22team['Time'][1:])
# 0     9 days 23:03:03
# 1     9 days 23:40:36
# 2     9 days 23:47:57
# 3    10 days 00:51:48
# 4    10 days 01:14:25
# 5    10 days 01:22:57
# 6    10 days 02:01:35
# 7    10 days 02:29:11
# 8    10 days 02:59:54
# 9    10 days 03:02:03
# 10   10 days 03:05:48
# 11   10 days 03:09:27
# 12   10 days 03:20:42
# 13   10 days 03:24:40
# 14   10 days 04:31:23
# 15   10 days 04:54:33
# 16   10 days 05:40:01
# 17   10 days 07:03:40
# 18   10 days 07:14:16
# 19   10 days 08:22:12
# 20   10 days 08:38:47
# 21   10 days 09:46:16
# Name: Time, dtype: timedelta64[ns]

# %%
TDF_22team['duration_mins'] = (TDF_22team['Time'].dt.total_seconds()/60).round(2)
TDF_22team.head
# Out:
# <bound method NDFrame.head of     Unnamed: 0.1  Unnamed: 0  Pos  Unnamed: 1  \
# 0              0           0    1         NaN
# 1              1           1    2         NaN
# 2              2           2    3         NaN
# 3              3           3    4         NaN
# 4              4           4    5         NaN
# 5              5           5    6         NaN
# 6              6           6    7         NaN
# 7              7           7    8         NaN
# 8              8           8    9         NaN
# 9              9           9   10         NaN
# 10            10          10   11         NaN
# 11            11          11   12         NaN
# 12            12          12   13         NaN
# 13            13          13   14         NaN
# 14            14          14   15         NaN
# 15            15          15   16         NaN
# 16            16          16   17         NaN
# 17            17          17   18         NaN
# 18            18          18   19         NaN
# ...

# %%
TDF_22 = TDF_22[['Time', 'duration_mins']]
TDF_22
# Out:
#                Time  duration_mins
# 0   3 days 07:33:20        4773.33
# 1   3 days 07:36:03        4776.05
# 2   3 days 07:40:42        4780.70
# 3   3 days 07:46:59        4786.98
# 4   3 days 07:49:06        4789.10
# ..              ...            ...
# 171             NaT            NaN
# 172             NaT            NaN
# 173             NaT            NaN
# 174             NaT            NaN
# 175             NaT            NaN
#
# [176 rows x 2 columns]

# %%
TDF_22team = TDF_22team[['Time', 'duration_mins']]
TDF_22team
# Out:
#                Time  duration_mins
# 0   9 days 23:03:03       14343.05
# 1   9 days 23:40:36       14380.60
# 2   9 days 23:47:57       14387.95
# 3  10 days 00:51:48       14451.80
# 4  10 days 01:14:25       14474.42
# 5  10 days 01:22:57       14482.95
# 6  10 days 02:01:35       14521.58
# 7  10 days 02:29:11       14549.18
# 8  10 days 02:59:54       14579.90
# 9  10 days 03:02:03       14582.05
# 10 10 days 03:05:48       14585.80
# 11 10 days 03:09:27       14589.45
# 12 10 days 03:20:42       14600.70
# 13 10 days 03:24:40       14604.67
# 14 10 days 04:31:23       14671.38
# 15 10 days 04:54:33       14694.55
# 16 10 days 05:40:01       14740.02
# 17 10 days 07:03:40       14823.67
# 18 10 days 07:14:16       14834.27
# 19 10 days 08:22:12       14902.20
# 20 10 days 08:38:47       14918.78
# 21 10 days 09:46:16       14986.27

# %%
# TDF_22team.to_csv('TDF_22team_timecleaned.csv')
# TDF_22.to_csv('TDF_22_timecleaned.csv')

# %% [markdown]
# ### TDF 2021

# %%
TDF_21 = pd.read_excel(r'D:\enzo\Documents\Data Science\Bike Prices\TDF2021\TDF_2021_timecleaned.xlsx')
TDF_21
# Out:
#      Unnamed: 0.1  Unnamed: 0  Pos  Unnamed: 1  Unnamed: 2  \
# 0               0           0    1         NaN         NaN
# 1               1           1    2         NaN         NaN
# 2               2           2    3         NaN         NaN
# 3               3           3    4         NaN         NaN
# 4               4           4    5         NaN         NaN
# ..            ...         ...  ...         ...         ...
# 179           179         179  DNF         NaN         NaN
# 180           180         180  DNF         NaN         NaN
# 181           181         181  DNF         NaN         NaN
# 182           182         182  DNF         NaN         NaN
# 183           183         183  DNF         NaN         NaN
#
#                     Rider                   Team     UCI      Time  \
# 0           Pogacar Tadej      UAE Team Emirates  1000.0  82:56:36
# 1        Vingegaard Jonas            Jumbo-Visma   800.0  00:05:20
# ...

# %%
TDF_21['Time'] = pd.to_timedelta(TDF_21['Time'])
TDF_21
# Out:
#      Unnamed: 0.1  Unnamed: 0  Pos  Unnamed: 1  Unnamed: 2  \
# 0               0           0    1         NaN         NaN
# 1               1           1    2         NaN         NaN
# 2               2           2    3         NaN         NaN
# 3               3           3    4         NaN         NaN
# 4               4           4    5         NaN         NaN
# ..            ...         ...  ...         ...         ...
# 179           179         179  DNF         NaN         NaN
# 180           180         180  DNF         NaN         NaN
# 181           181         181  DNF         NaN         NaN
# 182           182         182  DNF         NaN         NaN
# 183           183         183  DNF         NaN         NaN
#
#                     Rider                   Team     UCI            Time  \
# 0           Pogacar Tadej      UAE Team Emirates  1000.0 3 days 10:56:36
# 1        Vingegaard Jonas            Jumbo-Visma   800.0 0 days 00:05:20
# ...

# %%
TDF_21['Time'].loc[1:] = TDF_21['Time'][0] + (TDF_21['Time'][1:])
TDF_21['Time']
# Out:
# C:\Users\enzo\AppData\Local\Temp\ipykernel_1704\1502617651.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   TDF_21['Time'].loc[1:] = TDF_21['Time'][0] + (TDF_21['Time'][1:])
# 0     3 days 10:56:36
# 1     3 days 11:01:56
# 2     3 days 11:03:39
# 3     3 days 11:06:38
# 4     3 days 11:06:49
#             ...
# 179               NaT
# 180               NaT
# 181               NaT
# 182               NaT
# 183               NaT
# Name: Time, Length: 184, dtype: timedelta64[ns]

# %%
TDF_21['duration_mins'] = (TDF_21['Time'].dt.total_seconds()/60).round(2)
TDF_21.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0 Pos  Unnamed: 1  Unnamed: 2             Rider  \
# 0             0           0   1         NaN         NaN     Pogacar Tadej
# 1             1           1   2         NaN         NaN  Vingegaard Jonas
# 2             2           2   3         NaN         NaN   Carapaz Richard
# 3             3           3   4         NaN         NaN      O'Connor Ben
# 4             4           4   5         NaN         NaN   Kelderman Wilco
#
#                 Team     UCI            Time           Unnamed: 8  \
# 0  UAE Team Emirates  1000.0 3 days 10:56:36             82:56:36
# 1        Jumbo-Visma   800.0 3 days 11:01:56  1900-01-03 11:01:56
# 2   INEOS Grenadiers   675.0 3 days 11:03:39  1900-01-03 11:03:39
# 3  AG2R Citroën Team   575.0 3 days 11:06:38  1900-01-03 11:06:38
# 4     BORA-hansgrohe   475.0 3 days 11:06:49  1900-01-03 11:06:49
#
#    duration_mins
# 0        4976.60
# 1        4981.93
# 2        4983.65
# 3        4986.63
# 4        4986.82

# %%
TDF_21 = TDF_21[['Time', 'duration_mins']]
TDF_21
# Out:
#                Time  duration_mins
# 0   3 days 10:56:36        4976.60
# 1   3 days 11:01:56        4981.93
# 2   3 days 11:03:39        4983.65
# 3   3 days 11:06:38        4986.63
# 4   3 days 11:06:49        4986.82
# ..              ...            ...
# 179             NaT            NaN
# 180             NaT            NaN
# 181             NaT            NaN
# 182             NaT            NaN
# 183             NaT            NaN
#
# [184 rows x 2 columns]

# %%
TDF_team21 = pd.read_excel(r'D:\enzo\Documents\Data Science\Bike Prices\TDF2021\TDF 2021 Team timecleaned.xlsx')
TDF_team21
# Out:
#     Unnamed: 0.1  Unnamed: 0  Pos  Unnamed: 1  \
# 0              0           0    1         NaN
# 1              1           1    2         NaN
# 2              2           2    3         NaN
# 3              3           3    4         NaN
# 4              4           4    5         NaN
# 5              5           5    6         NaN
# 6              6           6    7         NaN
# 7              7           7    8         NaN
# 8              8           8    9         NaN
# 9              9           9   10         NaN
# 10            10          10   11         NaN
# 11            11          11   12         NaN
# 12            12          12   13         NaN
# 13            13          13   14         NaN
# 14            14          14   15         NaN
# 15            15          15   16         NaN
# 16            16          16   17         NaN
# 17            17          17   18         NaN
# 18            18          18   19         NaN
# ...

# %%
TDF_team21['Time'] = pd.to_timedelta(TDF_team21['Time'])
TDF_team21
# Out:
#     Unnamed: 0.1  Unnamed: 0  Pos  Unnamed: 1  \
# 0              0           0    1         NaN
# 1              1           1    2         NaN
# 2              2           2    3         NaN
# 3              3           3    4         NaN
# 4              4           4    5         NaN
# 5              5           5    6         NaN
# 6              6           6    7         NaN
# 7              7           7    8         NaN
# 8              8           8    9         NaN
# 9              9           9   10         NaN
# 10            10          10   11         NaN
# 11            11          11   12         NaN
# 12            12          12   13         NaN
# 13            13          13   14         NaN
# 14            14          14   15         NaN
# 15            15          15   16         NaN
# 16            16          16   17         NaN
# 17            17          17   18         NaN
# 18            18          18   19         NaN
# ...

# %%
TDF_team21['Time'].loc[1:] = TDF_team21['Time'][0] + (TDF_team21['Time'][1:])
TDF_team21['Time']
# Out:
# C:\Users\enzo\AppData\Local\Temp\ipykernel_1704\2142121361.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   TDF_team21['Time'].loc[1:] = TDF_team21['Time'][0] + (TDF_team21['Time'][1:])
# 0    10 days 09:16:47
# 1    10 days 09:35:59
# 2    10 days 10:28:22
# 3    10 days 10:43:57
# 4    10 days 10:48:41
# 5    10 days 10:53:31
# 6    10 days 11:03:51
# 7    10 days 11:18:32
# 8    10 days 11:21:15
# 9    10 days 11:54:55
# 10   10 days 12:53:34
# 11   10 days 12:59:57
# 12   10 days 13:03:13
# 13   10 days 13:07:09
# 14   10 days 13:32:21
# 15   10 days 13:48:18
# 16   10 days 14:18:49
# 17   10 days 15:07:25
# 18   10 days 15:09:03
# 19   10 days 15:24:16
# 20   10 days 16:12:39
# 21   10 days 16:50:16
# 22   10 days 17:02:31
# Name: Time, dtype: timedelta64[ns]

# %%
TDF_team21['duration_mins'] = (TDF_team21['Time'].dt.total_seconds()/60).round(2)
TDF_team21.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0  Pos  Unnamed: 1                Team  \
# 0             0           0    1         NaN  Bahrain Victorious
# 1             1           1    2         NaN  EF Education-NIPPO
# 2             2           2    3         NaN         Jumbo-Visma
# 3             3           3    4         NaN    INEOS Grenadiers
# 4             4           4    5         NaN   AG2R Citroën Team
#
#               Time        Time Adjusted  duration_mins
# 0 10 days 09:16:47            249:16:47       14956.78
# 1 10 days 09:35:59  1900-01-10 09:35:59       14975.98
# 2 10 days 10:28:22  1900-01-10 10:28:22       15028.37
# 3 10 days 10:43:57  1900-01-10 10:43:57       15043.95
# 4 10 days 10:48:41  1900-01-10 10:48:41       15048.68

# %%
TDF_team21 = TDF_team21[['Time', 'duration_mins']]
TDF_team21
# Out:
#                Time  duration_mins
# 0  10 days 09:16:47       14956.78
# 1  10 days 09:35:59       14975.98
# 2  10 days 10:28:22       15028.37
# 3  10 days 10:43:57       15043.95
# 4  10 days 10:48:41       15048.68
# 5  10 days 10:53:31       15053.52
# 6  10 days 11:03:51       15063.85
# 7  10 days 11:18:32       15078.53
# 8  10 days 11:21:15       15081.25
# 9  10 days 11:54:55       15114.92
# 10 10 days 12:53:34       15173.57
# 11 10 days 12:59:57       15179.95
# 12 10 days 13:03:13       15183.22
# 13 10 days 13:07:09       15187.15
# 14 10 days 13:32:21       15212.35
# 15 10 days 13:48:18       15228.30
# 16 10 days 14:18:49       15258.82
# 17 10 days 15:07:25       15307.42
# 18 10 days 15:09:03       15309.05
# 19 10 days 15:24:16       15324.27
# 20 10 days 16:12:39       15372.65
# 21 10 days 16:50:16       15410.27
# 22 10 days 17:02:31       15422.52

# %%
# TDF_21.to_csv('TDF_21 time cleaned.csv')
# TDF_team21.to_csv('TDF_team21 time cleaned.csv')

# %% [markdown]
# ### TDF 2020

# %%
TDF_20 = pd.read_excel(r'D:\enzo\Documents\Data Science\Bike Prices\TDF 2020\TDF_2020_GC timecleaned.xlsx')
TDF_20
# Out:
#      Unnamed: 0.1  Unnamed: 0  Pos  Unnamed: 1  Unnamed: 2             Rider  \
# 0               0           0    1         NaN         NaN     Pogacar Tadej
# 1               1           1    2         NaN         NaN     Roglic Primoz
# 2               2           2    3         NaN         NaN      Porte Richie
# 3               3           3    4         NaN         NaN       Landa Mikel
# 4               4           4    5         NaN         NaN         Mas Enric
# ..            ...         ...  ...         ...         ...               ...
# 171           171         171  DNF         NaN         NaN  Calmejane Lilian
# 172           172         172  DNF         NaN         NaN     Cousin Jérôme
# 173           173         173  DNF         NaN         NaN     Mollema Bauke
# 174           174         174  DNF         NaN         NaN         Aru Fabio
# 175           175         175  DNF         NaN         NaN    Formolo Davide
#
# ...

# %%
TDF_20['Time'] = pd.to_timedelta(TDF_20['Time'])
TDF_20
# Out:
#      Unnamed: 0.1  Unnamed: 0  Pos  Unnamed: 1  Unnamed: 2             Rider  \
# 0               0           0    1         NaN         NaN     Pogacar Tadej
# 1               1           1    2         NaN         NaN     Roglic Primoz
# 2               2           2    3         NaN         NaN      Porte Richie
# 3               3           3    4         NaN         NaN       Landa Mikel
# 4               4           4    5         NaN         NaN         Mas Enric
# ..            ...         ...  ...         ...         ...               ...
# 171           171         171  DNF         NaN         NaN  Calmejane Lilian
# 172           172         172  DNF         NaN         NaN     Cousin Jérôme
# 173           173         173  DNF         NaN         NaN     Mollema Bauke
# 174           174         174  DNF         NaN         NaN         Aru Fabio
# 175           175         175  DNF         NaN         NaN    Formolo Davide
#
# ...

# %%
TDF_20['Time'].loc[1:] = TDF_20['Time'][0] + (TDF_20['Time'][1:])
TDF_20['Time']
# Out:
# C:\Users\enzo\AppData\Local\Temp\ipykernel_1704\1646170131.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   TDF_20['Time'].loc[1:] = TDF_20['Time'][0] + (TDF_20['Time'][1:])
# 0     3 days 15:20:05
# 1     3 days 15:21:04
# 2     3 days 15:23:35
# 3     3 days 15:26:03
# 4     3 days 15:26:12
#             ...
# 171               NaT
# 172               NaT
# 173               NaT
# 174               NaT
# 175               NaT
# Name: Time, Length: 176, dtype: timedelta64[ns]

# %%
TDF_20['duration_mins'] = (TDF_20['Time'].dt.total_seconds()/60).round(2)
TDF_20.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0 Pos  Unnamed: 1  Unnamed: 2          Rider  \
# 0             0           0   1         NaN         NaN  Pogacar Tadej
# 1             1           1   2         NaN         NaN  Roglic Primoz
# 2             2           2   3         NaN         NaN   Porte Richie
# 3             3           3   4         NaN         NaN    Landa Mikel
# 4             4           4   5         NaN         NaN      Mas Enric
#
#                 Team     UCI            Time Unnamed: 9          Unnamed: 10  \
# 0  UAE Team Emirates  1000.0 3 days 15:20:05   87:20:05             87:20:05
# 1   Team Jumbo-Visma   800.0 3 days 15:21:04   00:00:59  1900-01-03 15:21:04
# 2     Trek-Segafredo   675.0 3 days 15:23:35   00:03:30  1900-01-03 15:23:35
# 3    Bahrain-McLaren   575.0 3 days 15:26:03   00:05:58  1900-01-03 15:26:03
# 4      Movistar Team   475.0 3 days 15:26:12   00:06:07  1900-01-03 15:26:12
#
#    duration_mins
# 0        5240.08
# 1        5241.07
# 2        5243.58
# ...

# %%
TDF_20[['Time','duration_mins']]
# Out:
#                Time  duration_mins
# 0   3 days 15:20:05        5240.08
# 1   3 days 15:21:04        5241.07
# 2   3 days 15:23:35        5243.58
# 3   3 days 15:26:03        5246.05
# 4   3 days 15:26:12        5246.20
# ..              ...            ...
# 171             NaT            NaN
# 172             NaT            NaN
# 173             NaT            NaN
# 174             NaT            NaN
# 175             NaT            NaN
#
# [176 rows x 2 columns]

# %%
TDF_20[['Time','duration_mins']].to_csv('TDF_20 Time_Duration_mins cleaned.csv')

# %% [markdown]
# ### GIRO 2022

# %%
GIRO_22 = pd.read_excel(r'D:\enzo\Documents\Data Science\Bike Prices\GIRO 2022\2022 GIRO.xlsx', sheet_name='GC')
GIRO_22.head(35)
# Out:
#     Unnamed: 0 Pos  Unnamed: 1  Unnamed: 2               Rider  \
# 0            0   1         NaN         NaN         Hindley Jai
# 1            1   2         NaN         NaN     Carapaz Richard
# 2            2   3         NaN         NaN         Landa Mikel
# 3            3   4         NaN         NaN     Nibali Vincenzo
# 4            4   5         NaN         NaN        Bilbao Pello
# 5            5   6         NaN         NaN            Hirt Jan
# 6            6   7         NaN         NaN    Buchmann Emanuel
# 7            7   8         NaN         NaN  Pozzovivo Domenico
# 8            8   9         NaN         NaN         Carthy Hugh
# 9            9  10         NaN         NaN    Lopez Juan Pedro
# 10          10  11         NaN         NaN  Valverde Alejandro
# 11          11  12         NaN         NaN   Buitrago Santiago
# 12          12  13         NaN         NaN      Hamilton Lucas
# 13          13  14         NaN         NaN    Martin Guillaume
# ...

# %%
GIRO_22['Time'][1:19] = GIRO_22['Time'][1:19].str.replace('+','00:')
GIRO_22.head(25)
# Out:
# C:\Users\enzo\AppData\Local\Temp\ipykernel_1704\2081954306.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   GIRO_22['Time'][1:19] = GIRO_22['Time'][1:19].str.replace('+','00:')
# C:\Users\enzo\AppData\Local\Temp\ipykernel_1704\2081954306.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   GIRO_22['Time'][1:19] = GIRO_22['Time'][1:19].str.replace('+','00:')
#     Unnamed: 0 Pos  Unnamed: 1  Unnamed: 2               Rider  \
# 0            0   1         NaN         NaN         Hindley Jai
# 1            1   2         NaN         NaN     Carapaz Richard
# 2            2   3         NaN         NaN         Landa Mikel
# ...

# %%
GIRO_22['Time'][19:] = GIRO_22['Time'][19:].str.replace('+', '')
GIRO_22.head(25)
# Out:
# C:\Users\enzo\AppData\Local\Temp\ipykernel_1704\491726330.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   GIRO_22['Time'][19:] = GIRO_22['Time'][19:].str.replace('+', '')
# C:\Users\enzo\AppData\Local\Temp\ipykernel_1704\491726330.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   GIRO_22['Time'][19:] = GIRO_22['Time'][19:].str.replace('+', '')
#     Unnamed: 0 Pos  Unnamed: 1  Unnamed: 2               Rider  \
# 0            0   1         NaN         NaN         Hindley Jai
# 1            1   2         NaN         NaN     Carapaz Richard
# 2            2   3         NaN         NaN         Landa Mikel
# ...

# %%
GIRO_22['Time'] = GIRO_22['Time'].str.replace(' ', '')
GIRO_22
# Out:
#      Unnamed: 0  Pos  Unnamed: 1  Unnamed: 2            Rider  \
# 0             0    1         NaN         NaN      Hindley Jai
# 1             1    2         NaN         NaN  Carapaz Richard
# 2             2    3         NaN         NaN      Landa Mikel
# 3             3    4         NaN         NaN  Nibali Vincenzo
# 4             4    5         NaN         NaN     Bilbao Pello
# ..          ...  ...         ...         ...              ...
# 171         171  DNF         NaN         NaN   Mørkøv Michael
# 172         172  DNF         NaN         NaN      Yates Simon
# 173         173  DNF         NaN         NaN    Bardet Romain
# 174         174  DNF         NaN         NaN         Bol Cees
# 175         175  DNF         NaN         NaN     Almeida Joao
#
#                             Team    UCI      Time
# 0                 BORA-hansgrohe  850.0  86:31:14
# 1               INEOS Grenadiers  680.0  00:01:18
# 2             Bahrain Victorious  575.0  00:03:24
# ...

# %%
GIRO_22['Time'] = pd.to_timedelta(GIRO_22['Time'])
GIRO_22['Time']
# Out:
# 0     3 days 14:31:14
# 1     0 days 00:01:18
# 2     0 days 00:03:24
# 3     0 days 00:09:02
# 4     0 days 00:09:14
#             ...
# 171               NaT
# 172               NaT
# 173               NaT
# 174               NaT
# 175               NaT
# Name: Time, Length: 176, dtype: timedelta64[ns]

# %%
GIRO_22['Time'].loc[1:] = GIRO_22['Time'][0] + (GIRO_22['Time'][1:])
GIRO_22['Time']
# Out:
# C:\Users\enzo\AppData\Local\Temp\ipykernel_1704\986137562.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   GIRO_22['Time'].loc[1:] = GIRO_22['Time'][0] + (GIRO_22['Time'][1:])
# 0     3 days 14:31:14
# 1     3 days 14:32:32
# 2     3 days 14:34:38
# 3     3 days 14:40:16
# 4     3 days 14:40:28
#             ...
# 171               NaT
# 172               NaT
# 173               NaT
# 174               NaT
# 175               NaT
# Name: Time, Length: 176, dtype: timedelta64[ns]

# %%
GIRO_22['duration_mins'] = (GIRO_22['Time'].dt.total_seconds()/60).round(2)
GIRO_22.head()
# Out:
#    Unnamed: 0 Pos  Unnamed: 1  Unnamed: 2            Rider  \
# 0           0   1         NaN         NaN      Hindley Jai
# 1           1   2         NaN         NaN  Carapaz Richard
# 2           2   3         NaN         NaN      Landa Mikel
# 3           3   4         NaN         NaN  Nibali Vincenzo
# 4           4   5         NaN         NaN     Bilbao Pello
#
#                     Team    UCI            Time  duration_mins
# 0         BORA-hansgrohe  850.0 3 days 14:31:14        5191.23
# 1       INEOS Grenadiers  680.0 3 days 14:32:32        5192.53
# 2     Bahrain Victorious  575.0 3 days 14:34:38        5194.63
# 3  Astana Qazaqstan Team  460.0 3 days 14:40:16        5200.27
# 4     Bahrain Victorious  380.0 3 days 14:40:28        5200.47

# %%
GIRO_22team = pd.read_excel(r'D:\enzo\Documents\Data Science\Bike Prices\GIRO 2022\2022 GIRO.xlsx', sheet_name= 'Team')
GIRO_22team.head()
# Out:
#    Unnamed: 0  Pos  Unnamed: 1                                Team        Time
# 0           0    1         NaN                  Bahrain Victorious   259:48:12
# 1           1    2         NaN                      BORA-hansgrohe     + 04:07
# 2           2    3         NaN                    INEOS Grenadiers  + 01:22:29
# 3           3    4         NaN  Intermarché-Wanty-Gobert Matériaux  + 01:23:57
# 4           4    5         NaN               Astana Qazaqstan Team  + 02:18:46

# %%
GIRO_22team['Time'][1] = GIRO_22team['Time'][1].replace('+','00:')
GIRO_22team.head()
# Out:
# C:\Users\enzo\AppData\Local\Temp\ipykernel_1704\2297165175.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   GIRO_22team['Time'][1] = GIRO_22team['Time'][1].replace('+','00:')
#    Unnamed: 0  Pos  Unnamed: 1                                Team        Time
# 0           0    1         NaN                  Bahrain Victorious   259:48:12
# 1           1    2         NaN                      BORA-hansgrohe   00: 04:07
# 2           2    3         NaN                    INEOS Grenadiers  + 01:22:29
# 3           3    4         NaN  Intermarché-Wanty-Gobert Matériaux  + 01:23:57
# 4           4    5         NaN               Astana Qazaqstan Team  + 02:18:46

# %%
GIRO_22team['Time'][2:] = GIRO_22team['Time'][2:].str.replace('+','')
GIRO_22team.head()
# Out:
# C:\Users\enzo\AppData\Local\Temp\ipykernel_1704\2057188857.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   GIRO_22team['Time'][2:] = GIRO_22team['Time'][2:].str.replace('+','')
# C:\Users\enzo\AppData\Local\Temp\ipykernel_1704\2057188857.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   GIRO_22team['Time'][2:] = GIRO_22team['Time'][2:].str.replace('+','')
#    Unnamed: 0  Pos  Unnamed: 1                                Team       Time
# 0           0    1         NaN                  Bahrain Victorious  259:48:12
# 1           1    2         NaN                      BORA-hansgrohe  00: 04:07
# ...

# %%
GIRO_22team['Time'] = GIRO_22team['Time'].str.replace(' ', '')
GIRO_22team.head()
# Out:
#    Unnamed: 0  Pos  Unnamed: 1                                Team       Time
# 0           0    1         NaN                  Bahrain Victorious  259:48:12
# 1           1    2         NaN                      BORA-hansgrohe   00:04:07
# 2           2    3         NaN                    INEOS Grenadiers   01:22:29
# 3           3    4         NaN  Intermarché-Wanty-Gobert Matériaux   01:23:57
# 4           4    5         NaN               Astana Qazaqstan Team   02:18:46

# %%
GIRO_22team['Time'] = pd.to_timedelta(GIRO_22team['Time'])
GIRO_22team.head()
# Out:
#    Unnamed: 0  Pos  Unnamed: 1                                Team  \
# 0           0    1         NaN                  Bahrain Victorious
# 1           1    2         NaN                      BORA-hansgrohe
# 2           2    3         NaN                    INEOS Grenadiers
# 3           3    4         NaN  Intermarché-Wanty-Gobert Matériaux
# 4           4    5         NaN               Astana Qazaqstan Team
#
#               Time
# 0 10 days 19:48:12
# 1  0 days 00:04:07
# 2  0 days 01:22:29
# 3  0 days 01:23:57
# 4  0 days 02:18:46

# %%
GIRO_22team['Time'].loc[1:] = GIRO_22team['Time'][0] + (GIRO_22team['Time'][1:])
GIRO_22team['Time']
# Out:
# C:\Users\enzo\AppData\Local\Temp\ipykernel_1704\1775618055.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   GIRO_22team['Time'].loc[1:] = GIRO_22team['Time'][0] + (GIRO_22team['Time'][1:])
# 0    10 days 19:48:12
# 1    10 days 19:52:19
# 2    10 days 21:10:41
# 3    10 days 21:12:09
# 4    10 days 22:06:58
# 5    10 days 22:09:22
# 6    10 days 22:28:28
# 7    10 days 23:09:14
# 8    10 days 23:18:10
# 9    10 days 23:27:57
# 10   11 days 00:18:04
# 11   11 days 01:05:45
# 12   11 days 01:29:00
# 13   11 days 01:37:26
# 14   11 days 01:39:50
# 15   11 days 02:01:30
# 16   11 days 04:03:33
# 17   11 days 04:55:39
# 18   11 days 06:25:28
# 19   11 days 07:05:15
# 20   11 days 07:10:05
# 21   11 days 09:44:19
# Name: Time, dtype: timedelta64[ns]

# %%
GIRO_22team['duration_mins'] = (GIRO_22team['Time'].dt.total_seconds()/60).round(2)
GIRO_22team.head()
# Out:
#    Unnamed: 0  Pos  Unnamed: 1                                Team  \
# 0           0    1         NaN                  Bahrain Victorious
# 1           1    2         NaN                      BORA-hansgrohe
# 2           2    3         NaN                    INEOS Grenadiers
# 3           3    4         NaN  Intermarché-Wanty-Gobert Matériaux
# 4           4    5         NaN               Astana Qazaqstan Team
#
#               Time  duration_mins
# 0 10 days 19:48:12       15588.20
# 1 10 days 19:52:19       15592.32
# 2 10 days 21:10:41       15670.68
# 3 10 days 21:12:09       15672.15
# 4 10 days 22:06:58       15726.97

# %%
GIRO_22[['Time', 'duration_mins']].to_csv('GIRO_22 timecleaned.csv')

# %%
GIRO_22team[['Time','duration_mins']].to_csv('GIRO_22team time cleaned.csv')

# %% [markdown]
# ### GIRO 2021

# %%
GIRO_21 = pd.read_excel(r'D:\enzo\Documents\Data Science\Bike Prices\GIRO 2021\2021 GIRO.xlsx', sheet_name= 'GC')
GIRO_21.head(25)
# Out:
#     Unnamed: 0 Pos  Unnamed: 1  Unnamed: 2                 Rider  \
# 0            0   1         NaN         NaN           Bernal Egan
# 1            1   2         NaN         NaN        Caruso Damiano
# 2            2   3         NaN         NaN           Yates Simon
# 3            3   4         NaN         NaN      Vlasov Aleksandr
# 4            4   5         NaN         NaN       Martinez Daniel
# 5            5   6         NaN         NaN          Almeida Joao
# 6            6   7         NaN         NaN         Bardet Romain
# 7            7   8         NaN         NaN           Carthy Hugh
# 8            8   9         NaN         NaN           Foss Tobias
# 9            9  10         NaN         NaN         Martin Daniel
# 10          10  11         NaN         NaN        Bennett George
# 11          11  12         NaN         NaN          Bouwman Koen
# 12          12  13         NaN         NaN          Bilbao Pello
# ...

# %%
GIRO_21['Time'][1:17] = GIRO_21['Time'][1:17].str.replace('+','00:')
GIRO_21.head()
# Out:
# C:\Users\enzo\AppData\Local\Temp\ipykernel_1704\4056487707.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   GIRO_21['Time'][1:17] = GIRO_21['Time'][1:17].str.replace('+','00:')
# C:\Users\enzo\AppData\Local\Temp\ipykernel_1704\4056487707.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   GIRO_21['Time'][1:17] = GIRO_21['Time'][1:17].str.replace('+','00:')
#    Unnamed: 0 Pos  Unnamed: 1  Unnamed: 2             Rider  \
# 0           0   1         NaN         NaN       Bernal Egan
# 1           1   2         NaN         NaN    Caruso Damiano
# 2           2   3         NaN         NaN       Yates Simon
# ...

# %%
GIRO_21['Time'][17:] = GIRO_21['Time'][17:].str.replace('+','')
GIRO_21.head()
# Out:
# C:\Users\enzo\AppData\Local\Temp\ipykernel_1704\1137847483.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   GIRO_21['Time'][17:] = GIRO_21['Time'][17:].str.replace('+','')
# C:\Users\enzo\AppData\Local\Temp\ipykernel_1704\1137847483.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   GIRO_21['Time'][17:] = GIRO_21['Time'][17:].str.replace('+','')
#    Unnamed: 0 Pos  Unnamed: 1  Unnamed: 2             Rider  \
# 0           0   1         NaN         NaN       Bernal Egan
# 1           1   2         NaN         NaN    Caruso Damiano
# 2           2   3         NaN         NaN       Yates Simon
# ...

# %%
GIRO_21['Time'] = GIRO_21['Time'].str.replace(' ', '')

# %%
GIRO_21.head()
# Out:
#    Unnamed: 0 Pos  Unnamed: 1  Unnamed: 2             Rider  \
# 0           0   1         NaN         NaN       Bernal Egan
# 1           1   2         NaN         NaN    Caruso Damiano
# 2           2   3         NaN         NaN       Yates Simon
# 3           3   4         NaN         NaN  Vlasov Aleksandr
# 4           4   5         NaN         NaN   Martinez Daniel
#
#                   Team    UCI      Time        Time Adjusted           Time.1  \
# 0     INEOS Grenadiers  850.0  86:17:28             86:17:28  3 days 14:17:28
# 1   Bahrain Victorious  680.0  00:01:29  1900-01-03 14:18:57  3 days 14:18:57
# 2    Team BikeExchange  575.0  00:04:15  1900-01-03 14:21:43  3 days 14:21:43
# 3  Astana-Premier Tech  460.0  00:06:40  1900-01-03 14:24:08  3 days 14:24:08
# 4     INEOS Grenadiers  380.0  00:07:24  1900-01-03 14:24:52  3 days 14:24:52
#
#    duration_mins
# 0        5177.47
# 1        5178.95
# 2        5181.72
# 3        5184.13
# 4        5184.87

# %%
GIRO_21['Time']= pd.to_timedelta(GIRO_21['Time'])
GIRO_21
# Out:
#      Unnamed: 0  Pos  Unnamed: 1  Unnamed: 2               Rider  \
# 0             0    1         NaN         NaN         Bernal Egan
# 1             1    2         NaN         NaN      Caruso Damiano
# 2             2    3         NaN         NaN         Yates Simon
# 3             3    4         NaN         NaN    Vlasov Aleksandr
# 4             4    5         NaN         NaN     Martinez Daniel
# ..          ...  ...         ...         ...                 ...
# 179         179  DNF         NaN         NaN     Nizzolo Giacomo
# 180         180  DNF         NaN         NaN  Pozzovivo Domenico
# 181         181  DNF         NaN         NaN  Brambilla Gianluca
# 182         182  DNF         NaN         NaN      Ciccone Giulio
# 183         183  DNF         NaN         NaN      Dombrowski Joe
#
#                       Team    UCI            Time        Time Adjusted  \
# 0         INEOS Grenadiers  850.0 3 days 14:17:28             86:17:28
# ...

# %%
GIRO_21['Time'].loc[1:] = GIRO_21['Time'][0] + (GIRO_21['Time'][1:])
GIRO_21['Time']
# Out:
# C:\Users\enzo\AppData\Local\Temp\ipykernel_1704\166374377.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   GIRO_21['Time'].loc[1:] = GIRO_21['Time'][0] + (GIRO_21['Time'][1:])
# 0     3 days 14:17:28
# 1     3 days 14:18:57
# 2     3 days 14:21:43
# 3     3 days 14:24:08
# 4     3 days 14:24:52
#             ...
# 179               NaT
# 180               NaT
# 181               NaT
# 182               NaT
# 183               NaT
# Name: Time, Length: 184, dtype: timedelta64[ns]

# %%
GIRO_21['duration_mins'] = (GIRO_21['Time'].dt.total_seconds()/60).round(2)
GIRO_21.head()
# Out:
#    Unnamed: 0 Pos  Unnamed: 1  Unnamed: 2             Rider  \
# 0           0   1         NaN         NaN       Bernal Egan
# 1           1   2         NaN         NaN    Caruso Damiano
# 2           2   3         NaN         NaN       Yates Simon
# 3           3   4         NaN         NaN  Vlasov Aleksandr
# 4           4   5         NaN         NaN   Martinez Daniel
#
#                   Team    UCI            Time        Time Adjusted  \
# 0     INEOS Grenadiers  850.0 3 days 14:17:28             86:17:28
# 1   Bahrain Victorious  680.0 3 days 14:18:57  1900-01-03 14:18:57
# 2    Team BikeExchange  575.0 3 days 14:21:43  1900-01-03 14:21:43
# 3  Astana-Premier Tech  460.0 3 days 14:24:08  1900-01-03 14:24:08
# 4     INEOS Grenadiers  380.0 3 days 14:24:52  1900-01-03 14:24:52
#
#             Time.1  duration_mins
# 0  3 days 14:17:28        5177.47
# 1  3 days 14:18:57        5178.95
# 2  3 days 14:21:43        5181.72
# 3  3 days 14:24:08        5184.13
# ...

# %%
# GIRO_21[['Time','duration_mins']].to_csv('GIRO_21 timecleaned.csv')

# %%
GIRO_21team = pd.read_excel(r'D:\enzo\Documents\Data Science\Bike Prices\GIRO 2021\2021 GIRO.xlsx', sheet_name= 'Team')
GIRO_21team
# Out:
#     Unnamed: 0  Pos  Unnamed: 1                                Team  \
# 0            0    1         NaN                    INEOS Grenadiers
# 1            1    2         NaN                         Jumbo-Visma
# 2            2    3         NaN                            Team DSM
# 3            3    4         NaN                 Astana-Premier Tech
# 4            4    5         NaN                   Team BikeExchange
# 5            5    6         NaN                      Trek-Segafredo
# 6            6    7         NaN                       Movistar Team
# 7            7    8         NaN               Deceuninck-Quick Step
# 8            8    9         NaN                  Bahrain Victorious
# 9            9   10         NaN                   UAE Team Emirates
# 10          10   11         NaN                  EF Education-NIPPO
# 11          11   12         NaN                        Groupama-FDJ
# 12          12   13         NaN            EOLO-KOMETA Cycling Team
# ...

# %%
GIRO_21team['Time'][1:4] = GIRO_21team['Time'][1:4].str.replace('+', '00:')
GIRO_21team.head()
# Out:
# C:\Users\enzo\AppData\Local\Temp\ipykernel_1704\3022589499.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   GIRO_21team['Time'][1:4] = GIRO_21team['Time'][1:4].str.replace('+', '00:')
# C:\Users\enzo\AppData\Local\Temp\ipykernel_1704\3022589499.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   GIRO_21team['Time'][1:4] = GIRO_21team['Time'][1:4].str.replace('+', '00:')
#    Unnamed: 0  Pos  Unnamed: 1                 Team        Time  \
# 0           0    1         NaN     INEOS Grenadiers   259:30:31
# 1           1    2         NaN          Jumbo-Visma   00: 26:52
# 2           2    3         NaN             Team DSM   00: 29:09
# ...

# %%
GIRO_21team['Time'][4:] = GIRO_21team['Time'][4:].str.replace('+', '')
GIRO_21team.head()
# Out:
# C:\Users\enzo\AppData\Local\Temp\ipykernel_1704\2148405233.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   GIRO_21team['Time'][4:] = GIRO_21team['Time'][4:].str.replace('+', '')
# C:\Users\enzo\AppData\Local\Temp\ipykernel_1704\2148405233.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   GIRO_21team['Time'][4:] = GIRO_21team['Time'][4:].str.replace('+', '')
#    Unnamed: 0  Pos  Unnamed: 1                 Team       Time  \
# 0           0    1         NaN     INEOS Grenadiers  259:30:31
# 1           1    2         NaN          Jumbo-Visma  00: 26:52
# 2           2    3         NaN             Team DSM  00: 29:09
# ...

# %%
GIRO_21team['Time'] = GIRO_21team['Time'].str.replace(' ', '')
GIRO_21team.head()
# Out:
#    Unnamed: 0  Pos  Unnamed: 1                 Team       Time  \
# 0           0    1         NaN     INEOS Grenadiers  259:30:31
# 1           1    2         NaN          Jumbo-Visma   00:26:52
# 2           2    3         NaN             Team DSM   00:29:09
# 3           3    4         NaN  Astana-Premier Tech   00:33:05
# 4           4    5         NaN    Team BikeExchange   01:15:12
#
#          Time Adjusted            Time.1  duration_mins
# 0            259:30:31  10 days 19:30:31       15570.52
# 1  1900-01-10 19:57:23   0 days 00:26:52          26.87
# 2  1900-01-10 19:59:40   0 days 00:29:09          29.15
# 3  1900-01-10 20:03:36   0 days 00:33:05          33.08
# 4  1900-01-10 20:45:43   0 days 01:15:12          75.20

# %%
GIRO_21team['Time'] = pd.to_timedelta(GIRO_21team['Time'])
GIRO_21team.head()
# Out:
#    Unnamed: 0  Pos  Unnamed: 1                 Team             Time  \
# 0           0    1         NaN     INEOS Grenadiers 10 days 19:30:31
# 1           1    2         NaN          Jumbo-Visma  0 days 00:26:52
# 2           2    3         NaN             Team DSM  0 days 00:29:09
# 3           3    4         NaN  Astana-Premier Tech  0 days 00:33:05
# 4           4    5         NaN    Team BikeExchange  0 days 01:15:12
#
#          Time Adjusted            Time.1  duration_mins
# 0            259:30:31  10 days 19:30:31       15570.52
# 1  1900-01-10 19:57:23   0 days 00:26:52          26.87
# 2  1900-01-10 19:59:40   0 days 00:29:09          29.15
# 3  1900-01-10 20:03:36   0 days 00:33:05          33.08
# 4  1900-01-10 20:45:43   0 days 01:15:12          75.20

# %%
GIRO_21team['duration_mins'] = (GIRO_21team['Time'].dt.total_seconds()/60).round(2)
GIRO_21team.head()
# Out:
#    Unnamed: 0  Pos  Unnamed: 1                 Team             Time  \
# 0           0    1         NaN     INEOS Grenadiers 10 days 19:30:31
# 1           1    2         NaN          Jumbo-Visma  0 days 00:26:52
# 2           2    3         NaN             Team DSM  0 days 00:29:09
# 3           3    4         NaN  Astana-Premier Tech  0 days 00:33:05
# 4           4    5         NaN    Team BikeExchange  0 days 01:15:12
#
#          Time Adjusted            Time.1  duration_mins
# 0            259:30:31  10 days 19:30:31       15570.52
# 1  1900-01-10 19:57:23   0 days 00:26:52          26.87
# 2  1900-01-10 19:59:40   0 days 00:29:09          29.15
# 3  1900-01-10 20:03:36   0 days 00:33:05          33.08
# 4  1900-01-10 20:45:43   0 days 01:15:12          75.20

# %%
# GIRO_21team[['Time','duration_mins']].to_csv('GIRO_21team timecleaned.csv')

# %% [markdown]
# ### GIRO 2020

# %%
GIRO_20 = pd.read_excel(r'D:\enzo\Documents\Data Science\Bike Prices\GIRO 2020\2020 GIRO.xlsx', sheet_name= 'GC')
GIRO_20.head(25)
# Out:
#     Unnamed: 0 Pos  Unnamed: 1  Unnamed: 2                   Rider  \
# 0            0   1         NaN         NaN      Geoghegan Hart Tao
# 1            1   2         NaN         NaN             Hindley Jai
# 2            2   3         NaN         NaN         Kelderman Wilco
# 3            3   4         NaN         NaN            Almeida Joao
# 4            4   5         NaN         NaN            Bilbao Pello
# 5            5   6         NaN         NaN          Fuglsang Jakob
# 6            6   7         NaN         NaN         Nibali Vincenzo
# 7            7   8         NaN         NaN          Konrad Patrick
# 8            8   9         NaN         NaN          Masnada Fausto
# 9            9  10         NaN         NaN     Pernsteiner Hermann
# 10          10  11         NaN         NaN      Pozzovivo Domenico
# 11          11  12         NaN         NaN             Majka Rafal
# 12          12  13         NaN         NaN         Samitier Sergio
# ...

# %%
GIRO_20['Time'][1] = GIRO_20['Time'][1].replace('+', '00:00:')
GIRO_20
# Out:
# C:\Users\enzo\AppData\Local\Temp\ipykernel_1704\2681312854.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   GIRO_20['Time'][1] = GIRO_20['Time'][1].replace('+', '00:00:')
#      Unnamed: 0  Pos  Unnamed: 1  Unnamed: 2                Rider  \
# 0             0    1         NaN         NaN   Geoghegan Hart Tao
# 1             1    2         NaN         NaN          Hindley Jai
# 2             2    3         NaN         NaN      Kelderman Wilco
# 3             3    4         NaN         NaN         Almeida Joao
# 4             4    5         NaN         NaN         Bilbao Pello
# ..          ...  ...         ...         ...                  ...
# 171         171  DNF         NaN         NaN     Molano Sebastian
# 172         172  DNF         NaN         NaN  Richeze Maximiliano
# ...

# %%
GIRO_20['Time'][2:19] = GIRO_20['Time'][2:19].str.replace('+', '00:')
GIRO_20
# Out:
# C:\Users\enzo\AppData\Local\Temp\ipykernel_1704\1617726535.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   GIRO_20['Time'][2:19] = GIRO_20['Time'][2:19].str.replace('+', '00:')
# C:\Users\enzo\AppData\Local\Temp\ipykernel_1704\1617726535.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   GIRO_20['Time'][2:19] = GIRO_20['Time'][2:19].str.replace('+', '00:')
#      Unnamed: 0  Pos  Unnamed: 1  Unnamed: 2                Rider  \
# 0             0    1         NaN         NaN   Geoghegan Hart Tao
# 1             1    2         NaN         NaN          Hindley Jai
# 2             2    3         NaN         NaN      Kelderman Wilco
# ...

# %%
GIRO_20['Time'][19:] = GIRO_20['Time'][19:].str.replace('+', '')
GIRO_20.head(24)
# Out:
# C:\Users\enzo\AppData\Local\Temp\ipykernel_1704\910681168.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   GIRO_20['Time'][19:] = GIRO_20['Time'][19:].str.replace('+', '')
# C:\Users\enzo\AppData\Local\Temp\ipykernel_1704\910681168.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   GIRO_20['Time'][19:] = GIRO_20['Time'][19:].str.replace('+', '')
#     Unnamed: 0 Pos  Unnamed: 1  Unnamed: 2                   Rider  \
# 0            0   1         NaN         NaN      Geoghegan Hart Tao
# 1            1   2         NaN         NaN             Hindley Jai
# 2            2   3         NaN         NaN         Kelderman Wilco
# ...

# %%
GIRO_20['Time'] = GIRO_20['Time'].str.replace(' ', '')
GIRO_20
# Out:
#      Unnamed: 0  Pos  Unnamed: 1  Unnamed: 2                Rider  \
# 0             0    1         NaN         NaN   Geoghegan Hart Tao
# 1             1    2         NaN         NaN          Hindley Jai
# 2             2    3         NaN         NaN      Kelderman Wilco
# 3             3    4         NaN         NaN         Almeida Joao
# 4             4    5         NaN         NaN         Bilbao Pello
# ..          ...  ...         ...         ...                  ...
# 171         171  DNF         NaN         NaN     Molano Sebastian
# 172         172  DNF         NaN         NaN  Richeze Maximiliano
# 173         173  DNF         NaN         NaN     Spreafico Matteo
# 174         174  DNF         NaN         NaN    Visconti Giovanni
# 175         175  DNF         NaN         NaN      Wackermann Luca
#
#                       Team    UCI      Time           Unnamed: 8  \
# 0         INEOS Grenadiers  850.0  85:40:21             85:40:21
# ...

# %%
GIRO_20['Time'] = pd.to_timedelta(GIRO_20['Time'])
GIRO_20
# Out:
#      Unnamed: 0  Pos  Unnamed: 1  Unnamed: 2                Rider  \
# 0             0    1         NaN         NaN   Geoghegan Hart Tao
# 1             1    2         NaN         NaN          Hindley Jai
# 2             2    3         NaN         NaN      Kelderman Wilco
# 3             3    4         NaN         NaN         Almeida Joao
# 4             4    5         NaN         NaN         Bilbao Pello
# ..          ...  ...         ...         ...                  ...
# 171         171  DNF         NaN         NaN     Molano Sebastian
# 172         172  DNF         NaN         NaN  Richeze Maximiliano
# 173         173  DNF         NaN         NaN     Spreafico Matteo
# 174         174  DNF         NaN         NaN    Visconti Giovanni
# 175         175  DNF         NaN         NaN      Wackermann Luca
#
#                       Team    UCI            Time           Unnamed: 8  \
# 0         INEOS Grenadiers  850.0 3 days 13:40:21             85:40:21
# ...

# %%
GIRO_20['duration_mins'] = (GIRO_20['Time'].dt.total_seconds()/60).round(2)
GIRO_20.head()
# Out:
#    Unnamed: 0 Pos  Unnamed: 1  Unnamed: 2               Rider  \
# 0           0   1         NaN         NaN  Geoghegan Hart Tao
# 1           1   2         NaN         NaN         Hindley Jai
# 2           2   3         NaN         NaN     Kelderman Wilco
# 3           3   4         NaN         NaN        Almeida Joao
# 4           4   5         NaN         NaN        Bilbao Pello
#
#                     Team    UCI            Time           Unnamed: 8  \
# 0       INEOS Grenadiers  850.0 3 days 13:40:21             85:40:21
# 1            Team Sunweb  680.0 0 days 00:00:39  1900-01-03 13:41:00
# 2            Team Sunweb  575.0 0 days 00:01:29  1900-01-03 13:41:50
# 3  Deceuninck-Quick Step  460.0 0 days 00:02:57  1900-01-03 13:43:18
# 4        Bahrain-McLaren  380.0 0 days 00:03:09  1900-01-03 13:43:30
#
#             Time.1  duration_mins
# 0  3 days 13:40:21        5140.35
# 1  0 days 00:00:39           0.65
# 2  0 days 00:01:29           1.48
# 3  0 days 00:02:57           2.95
# ...

# %%
# GIRO_20[['Time','duration_mins']].to_csv('GIRO_20 timecleaned.csv')

# %% [markdown]
# ### VUELTA 2022

# %%
VUELTA_22 = pd.read_excel(r'D:\enzo\Documents\Data Science\Bike Prices\VUELTA 2022\2022 VUELTA.xlsx',sheet_name='GC')
VUELTA_22.head(25)
# Out:
#     Unnamed: 0 Pos  Unnamed: 1  Unnamed: 2                  Rider  \
# 0            0   1         NaN         NaN        Evenepoel Remco
# 1            1   2         NaN         NaN              Mas Enric
# 2            2   3         NaN         NaN             Ayuso Juan
# 3            3   4         NaN         NaN     López Miguel Ángel
# 4            4   5         NaN         NaN           Almeida Joao
# 5            5   6         NaN         NaN        Arensman Thymen
# 6            6   7         NaN         NaN       Rodriguez Carlos
# 7            7   8         NaN         NaN           O'Connor Ben
# 8            8   9         NaN         NaN         Uran Rigoberto
# 9            9  10         NaN         NaN            Hindley Jai
# 10          10  11         NaN         NaN         Meintjes Louis
# 11          11  12         NaN         NaN             Polanc Jan
# 12          12  13         NaN         NaN     Valverde Alejandro
# ...

# %%
VUELTA_22['Time'][1:20] = VUELTA_22['Time'][1:20].str.replace('+','00:')
VUELTA_22.head()
# Out:
# C:\Users\enzo\AppData\Local\Temp\ipykernel_17340\1860983797.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   VUELTA_22['Time'][1:20] = VUELTA_22['Time'][1:20].str.replace('+','00:')
# C:\Users\enzo\AppData\Local\Temp\ipykernel_17340\1860983797.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   VUELTA_22['Time'][1:20] = VUELTA_22['Time'][1:20].str.replace('+','00:')
#    Unnamed: 0 Pos  Unnamed: 1  Unnamed: 2               Rider  \
# 0           0   1         NaN         NaN     Evenepoel Remco
# 1           1   2         NaN         NaN           Mas Enric
# 2           2   3         NaN         NaN          Ayuso Juan
# ...

# %%
VUELTA_22['Time'][20:] = VUELTA_22['Time'][20:].str.replace('+','')
VUELTA_22.head()
# Out:
# C:\Users\enzo\AppData\Local\Temp\ipykernel_17340\2830079204.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   VUELTA_22['Time'][20:] = VUELTA_22['Time'][20:].str.replace('+','')
# C:\Users\enzo\AppData\Local\Temp\ipykernel_17340\2830079204.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   VUELTA_22['Time'][20:] = VUELTA_22['Time'][20:].str.replace('+','')
#    Unnamed: 0 Pos  Unnamed: 1  Unnamed: 2               Rider  \
# 0           0   1         NaN         NaN     Evenepoel Remco
# 1           1   2         NaN         NaN           Mas Enric
# 2           2   3         NaN         NaN          Ayuso Juan
# ...

# %%
VUELTA_22['Time'] = VUELTA_22['Time'].str.replace(' ', '')
VUELTA_22.head()
# Out:
#    Unnamed: 0 Pos  Unnamed: 1  Unnamed: 2               Rider  \
# 0           0   1         NaN         NaN     Evenepoel Remco
# 1           1   2         NaN         NaN           Mas Enric
# 2           2   3         NaN         NaN          Ayuso Juan
# 3           3   4         NaN         NaN  López Miguel Ángel
# 4           4   5         NaN         NaN        Almeida Joao
#
#                           Team    UCI      Time        Time Adjusted
# 0  Quick-Step Alpha Vinyl Team  850.0  80:26:59             80:26:59
# 1                Movistar Team  680.0  00:02:02  1900-01-03 08:29:01
# 2            UAE Team Emirates  575.0  00:04:57  1900-01-03 08:31:56
# 3        Astana Qazaqstan Team  460.0  00:05:56  1900-01-03 08:32:55
# 4            UAE Team Emirates  380.0  00:07:24  1900-01-03 08:34:23

# %%
VUELTA_22['Time'] = pd.to_timedelta(VUELTA_22['Time'])
VUELTA_22
# Out:
#      Unnamed: 0  Pos  Unnamed: 1  Unnamed: 2               Rider  \
# 0             0    1         NaN         NaN     Evenepoel Remco
# 1             1    2         NaN         NaN           Mas Enric
# 2             2    3         NaN         NaN          Ayuso Juan
# 3             3    4         NaN         NaN  López Miguel Ángel
# 4             4    5         NaN         NaN        Almeida Joao
# ..          ...  ...         ...         ...                 ...
# 178         178  DNF         NaN         NaN         Yates Simon
# 179         179  DNF         NaN         NaN        Arndt Nikias
# 180         180  DNF         NaN         NaN        Donovan Mark
# 181         181  DNF         NaN         NaN  Vandenabeele Henri
# 182         182  DNF         NaN         NaN          Hoole Daan
#
#                             Team    UCI            Time        Time Adjusted
# 0    Quick-Step Alpha Vinyl Team  850.0 3 days 08:26:59             80:26:59
# ...

# %%
VUELTA_22['Time'].loc[1:] = VUELTA_22['Time'][0] + (VUELTA_22['Time'][1:])
VUELTA_22['Time']
# Out:
# C:\Users\enzo\AppData\Local\Temp\ipykernel_17340\2456368294.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   VUELTA_22['Time'].loc[1:] = VUELTA_22['Time'][0] + (VUELTA_22['Time'][1:])
# 0     3 days 08:26:59
# 1     3 days 08:29:01
# 2     3 days 08:31:56
# 3     3 days 08:32:55
# 4     3 days 08:34:23
#             ...
# 178               NaT
# 179               NaT
# 180               NaT
# 181               NaT
# 182               NaT
# Name: Time, Length: 183, dtype: timedelta64[ns]

# %%
VUELTA_22['duration_mins'] = (VUELTA_22['Time'].dt.total_seconds()/60).round(2)
VUELTA_22.head(25)
# Out:
#     Unnamed: 0 Pos  Unnamed: 1  Unnamed: 2                  Rider  \
# 0            0   1         NaN         NaN        Evenepoel Remco
# 1            1   2         NaN         NaN              Mas Enric
# 2            2   3         NaN         NaN             Ayuso Juan
# 3            3   4         NaN         NaN     López Miguel Ángel
# 4            4   5         NaN         NaN           Almeida Joao
# 5            5   6         NaN         NaN        Arensman Thymen
# 6            6   7         NaN         NaN       Rodriguez Carlos
# 7            7   8         NaN         NaN           O'Connor Ben
# 8            8   9         NaN         NaN         Uran Rigoberto
# 9            9  10         NaN         NaN            Hindley Jai
# 10          10  11         NaN         NaN         Meintjes Louis
# 11          11  12         NaN         NaN             Polanc Jan
# 12          12  13         NaN         NaN     Valverde Alejandro
# ...

# %%
VUELTA_22[['Time','duration_mins']].to_csv('VUELTA_22 timecleaned.csv')

# %%
VUELTA_22team = pd.read_excel(r'D:\enzo\Documents\Data Science\Bike Prices\VUELTA 2022\2022 VUELTA.xlsx',sheet_name='Team')
VUELTA_22team
# Out:
#     Unnamed: 0  Pos  Unnamed: 1                                Team  \
# 0            0    1         NaN                   UAE Team Emirates
# 1            1    2         NaN                    INEOS Grenadiers
# 2            2    3         NaN                       Movistar Team
# 3            3    4         NaN                  Bahrain Victorious
# 4            4    5         NaN               Astana Qazaqstan Team
# 5            5    6         NaN                      BORA-hansgrohe
# 6            6    7         NaN                         Jumbo-Visma
# 7            7    8         NaN               EF Education-EasyPost
# 8            8    9         NaN                        Groupama-FDJ
# 9            9   10         NaN         Quick-Step Alpha Vinyl Team
# 10          10   11         NaN  Intermarché-Wanty-Gobert Matériaux
# 11          11   12         NaN                           Burgos-BH
# 12          12   13         NaN                   AG2R Citroën Team
# ...

# %%
VUELTA_22team['Time'][1] = VUELTA_22team['Time'][1].replace('+', '00:')
VUELTA_22team
# Out:
# C:\Users\enzo\AppData\Local\Temp\ipykernel_1704\827120271.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   VUELTA_22team['Time'][1] = VUELTA_22team['Time'][1].replace('+', '00:')
#     Unnamed: 0  Pos  Unnamed: 1                                Team  \
# 0            0    1         NaN                   UAE Team Emirates
# 1            1    2         NaN                    INEOS Grenadiers
# 2            2    3         NaN                       Movistar Team
# 3            3    4         NaN                  Bahrain Victorious
# 4            4    5         NaN               Astana Qazaqstan Team
# 5            5    6         NaN                      BORA-hansgrohe
# 6            6    7         NaN                         Jumbo-Visma
# ...

# %%
VUELTA_22team['Time'][2:] = VUELTA_22team['Time'][2:].str.replace('+', '')
VUELTA_22team
# Out:
# C:\Users\enzo\AppData\Local\Temp\ipykernel_1704\2877488844.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   VUELTA_22team['Time'][2:] = VUELTA_22team['Time'][2:].str.replace('+', '')
# C:\Users\enzo\AppData\Local\Temp\ipykernel_1704\2877488844.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   VUELTA_22team['Time'][2:] = VUELTA_22team['Time'][2:].str.replace('+', '')
#     Unnamed: 0  Pos  Unnamed: 1                                Team  \
# 0            0    1         NaN                   UAE Team Emirates
# 1            1    2         NaN                    INEOS Grenadiers
# ...

# %%
VUELTA_22team['Time'] = VUELTA_22team['Time'].str.replace(' ', '')
VUELTA_22team
# Out:
#     Unnamed: 0  Pos  Unnamed: 1                                Team  \
# 0            0    1         NaN                   UAE Team Emirates
# 1            1    2         NaN                    INEOS Grenadiers
# 2            2    3         NaN                       Movistar Team
# 3            3    4         NaN                  Bahrain Victorious
# 4            4    5         NaN               Astana Qazaqstan Team
# 5            5    6         NaN                      BORA-hansgrohe
# 6            6    7         NaN                         Jumbo-Visma
# 7            7    8         NaN               EF Education-EasyPost
# 8            8    9         NaN                        Groupama-FDJ
# 9            9   10         NaN         Quick-Step Alpha Vinyl Team
# 10          10   11         NaN  Intermarché-Wanty-Gobert Matériaux
# 11          11   12         NaN                           Burgos-BH
# 12          12   13         NaN                   AG2R Citroën Team
# ...

# %%
VUELTA_22team['Time'] = pd.to_timedelta(VUELTA_22team['Time'])
VUELTA_22team.head()
# Out:
#    Unnamed: 0  Pos  Unnamed: 1                   Team             Time  \
# 0           0    1         NaN      UAE Team Emirates 10 days 00:36:32
# 1           1    2         NaN       INEOS Grenadiers  0 days 00:55:35
# 2           2    3         NaN          Movistar Team  0 days 01:16:52
# 3           3    4         NaN     Bahrain Victorious  0 days 01:17:36
# 4           4    5         NaN  Astana Qazaqstan Team  0 days 01:34:18
#
#          Time Adjusted            Time.1  duration_mins
# 0            240:36:32  10 days 00:36:32       14436.53
# 1  1900-01-10 01:32:07   0 days 00:55:35          55.58
# 2  1900-01-10 01:53:24   0 days 01:16:52          76.87
# 3  1900-01-10 01:54:08   0 days 01:17:36          77.60
# 4  1900-01-10 02:10:50   0 days 01:34:18          94.30

# %%
VUELTA_22team['duration_mins'] = (VUELTA_22team['Time'].dt.total_seconds()/60).round(2)
VUELTA_22team.head(25)
# Out:
#     Unnamed: 0  Pos  Unnamed: 1                                Team  \
# 0            0    1         NaN                   UAE Team Emirates
# 1            1    2         NaN                    INEOS Grenadiers
# 2            2    3         NaN                       Movistar Team
# 3            3    4         NaN                  Bahrain Victorious
# 4            4    5         NaN               Astana Qazaqstan Team
# 5            5    6         NaN                      BORA-hansgrohe
# 6            6    7         NaN                         Jumbo-Visma
# 7            7    8         NaN               EF Education-EasyPost
# 8            8    9         NaN                        Groupama-FDJ
# 9            9   10         NaN         Quick-Step Alpha Vinyl Team
# 10          10   11         NaN  Intermarché-Wanty-Gobert Matériaux
# 11          11   12         NaN                           Burgos-BH
# 12          12   13         NaN                   AG2R Citroën Team
# ...

# %%
# VUELTA_22team[['Time','duration_mins']].to_csv('VUELTA_22team timecleaned.csv')

# %% [markdown]
# ### VUELTA 2021

# %%
VUELTA_21 = pd.read_excel(r'D:\enzo\Documents\Data Science\Bike Prices\VUELTA 2021\2021 VUELTA.xlsx', sheet_name= 'GC')
VUELTA_21.head(25)
# Out:
#    Pos                 Rider                                Team    UCI  \
# 0    1         Roglic Primoz                         Jumbo-Visma  850.0
# 1    2             Mas Enric                       Movistar Team  680.0
# 2    3             Haig Jack                  Bahrain Victorious  575.0
# 3    4            Yates Adam                    INEOS Grenadiers  460.0
# 4    5            Mäder Gino                  Bahrain Victorious  380.0
# 5    6           Bernal Egan                    INEOS Grenadiers  320.0
# 6    7      De La Cruz David                   UAE Team Emirates  260.0
# 7    8             Kuss Sepp                         Jumbo-Visma  220.0
# 8    9      Martin Guillaume                             Cofidis  180.0
# 9   10   Großschartner Felix                      BORA-hansgrohe  140.0
# 10  11  Eiking Odd Christian  Intermarché-Wanty-Gobert Matériaux  120.0
# 11  12     Kruijswijk Steven                         Jumbo-Visma  100.0
# ...

# %%
VUELTA_21['Time'][1:16] = VUELTA_21['Time'][1:16].str.replace('+', '00:')
VUELTA_21
# Out:
# C:\Users\enzo\AppData\Local\Temp\ipykernel_16700\2560841171.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   VUELTA_21['Time'][1:16] = VUELTA_21['Time'][1:16].str.replace('+', '00:')
# C:\Users\enzo\AppData\Local\Temp\ipykernel_16700\2560841171.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   VUELTA_21['Time'][1:16] = VUELTA_21['Time'][1:16].str.replace('+', '00:')
#      Pos                        Rider                   Team    UCI       Time
# 0      1                Roglic Primoz            Jumbo-Visma  850.0   83:55:29
# 1      2                    Mas Enric          Movistar Team  680.0  00: 04:42
# ...

# %%
VUELTA_21['Time'][16:] = VUELTA_21['Time'][16:].str.replace('+', '')
VUELTA_21.head(25)
# Out:
# C:\Users\enzo\AppData\Local\Temp\ipykernel_16700\1180216845.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   VUELTA_21['Time'][16:] = VUELTA_21['Time'][16:].str.replace('+', '')
# C:\Users\enzo\AppData\Local\Temp\ipykernel_16700\1180216845.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   VUELTA_21['Time'][16:] = VUELTA_21['Time'][16:].str.replace('+', '')
#    Pos                 Rider                                Team    UCI  \
# 0    1         Roglic Primoz                         Jumbo-Visma  850.0
# 1    2             Mas Enric                       Movistar Team  680.0
# ...

# %%
VUELTA_21['Time'] = pd.to_timedelta(VUELTA_21['Time'])
VUELTA_21
# Out:
#      Pos                        Rider                   Team    UCI  \
# 0      1                Roglic Primoz            Jumbo-Visma  850.0
# 1      2                    Mas Enric          Movistar Team  680.0
# 2      3                    Haig Jack     Bahrain Victorious  575.0
# 3      4                   Yates Adam       INEOS Grenadiers  460.0
# 4      5                   Mäder Gino     Bahrain Victorious  380.0
# ..   ...                          ...                    ...    ...
# 179  DNF  Janse van Rensburg Reinardt  Team Qhubeka NextHash    NaN
# 180  DNF               Ciccone Giulio         Trek-Segafredo    NaN
# 181  DNF              Elissonde Kenny         Trek-Segafredo    NaN
# 182  DNF                 Reijnen Kiel         Trek-Segafredo    NaN
# 183  DNF             Molano Sebastian      UAE Team Emirates    NaN
#
#                Time
# 0   3 days 11:55:29
# 1   0 days 00:04:42
# 2   0 days 00:07:40
# 3   0 days 00:09:06
# 4   0 days 00:11:33
# ..              ...
# ...

# %%
VUELTA_21['Time'].loc[1:] = VUELTA_21['Time'][0] + (VUELTA_21['Time'][1:])
VUELTA_21['Time']
# Out:
# C:\Users\enzo\AppData\Local\Temp\ipykernel_16700\1139132270.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   VUELTA_21['Time'].loc[1:] = VUELTA_21['Time'][0] + (VUELTA_21['Time'][1:])
# 0     3 days 11:55:29
# 1     3 days 12:00:11
# 2     3 days 12:03:09
# 3     3 days 12:04:35
# 4     3 days 12:07:02
#             ...
# 179               NaT
# 180               NaT
# 181               NaT
# 182               NaT
# 183               NaT
# Name: Time, Length: 184, dtype: timedelta64[ns]

# %%
VUELTA_21['duration_mins'] = (VUELTA_21['Time'].dt.total_seconds()/60).round(2)
VUELTA_21.head(25)
# Out:
#    Pos                 Rider                                Team    UCI  \
# 0    1         Roglic Primoz                         Jumbo-Visma  850.0
# 1    2             Mas Enric                       Movistar Team  680.0
# 2    3             Haig Jack                  Bahrain Victorious  575.0
# 3    4            Yates Adam                    INEOS Grenadiers  460.0
# 4    5            Mäder Gino                  Bahrain Victorious  380.0
# 5    6           Bernal Egan                    INEOS Grenadiers  320.0
# 6    7      De La Cruz David                   UAE Team Emirates  260.0
# 7    8             Kuss Sepp                         Jumbo-Visma  220.0
# 8    9      Martin Guillaume                             Cofidis  180.0
# 9   10   Großschartner Felix                      BORA-hansgrohe  140.0
# 10  11  Eiking Odd Christian  Intermarché-Wanty-Gobert Matériaux  120.0
# 11  12     Kruijswijk Steven                         Jumbo-Visma  100.0
# ...

# %%
VUELTA_21[['Time', 'duration_mins']].to_csv('VUELTA_21 timecleaned.csv')

# %%
VUELTA_21team = pd.read_excel(r'D:\enzo\Documents\Data Science\Bike Prices\VUELTA 2021\2021 VUELTA.xlsx', sheet_name= 'Team')
VUELTA_21team
# Out:
#     Pos                                Team        Time            Time.1  \
# 0     1                  Bahrain Victorious   252:19:35  10 days 12:19:35
# 1     2                         Jumbo-Visma     + 07:26   0 days 00:07:26
# 2     3                    INEOS Grenadiers     + 32:18   0 days 00:32:18
# 3     4                   UAE Team Emirates  + 01:05:10   0 days 01:05:10
# 4     5  Intermarché-Wanty-Gobert Matériaux  + 01:15:05   0 days 01:15:05
# 5     6                       Movistar Team  + 01:17:16   0 days 01:17:16
# 6     7                   AG2R Citroën Team  + 01:43:04   0 days 01:43:04
# 7     8                             Cofidis  + 02:15:39   0 days 02:15:39
# 8     9                      Trek-Segafredo  + 02:38:20   0 days 02:38:20
# 9    10                            Team DSM  + 02:59:49   0 days 02:59:49
# 10   11                   Euskaltel-Euskadi  + 03:31:29   0 days 03:31:29
# 11   12                           Burgos-BH  + 03:49:37   0 days 03:49:37
# ...

# %%
VUELTA_21team['Time'][1:3] = VUELTA_21team['Time'][1:3].str.replace('+', '00:')
VUELTA_21team
# Out:
# C:\Users\enzo\AppData\Local\Temp\ipykernel_16700\3908388620.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   VUELTA_21team['Time'][1:3] = VUELTA_21team['Time'][1:3].str.replace('+', '00:')
# C:\Users\enzo\AppData\Local\Temp\ipykernel_16700\3908388620.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   VUELTA_21team['Time'][1:3] = VUELTA_21team['Time'][1:3].str.replace('+', '00:')
#     Pos                                Team        Time            Time.1  \
# 0     1                  Bahrain Victorious   252:19:35  10 days 12:19:35
# 1     2                         Jumbo-Visma   00: 07:26   0 days 00:07:26
# ...

# %%
VUELTA_21team['Time'][3:] = VUELTA_21team['Time'][3:].str.replace('+', '')
VUELTA_21team
# Out:
# C:\Users\enzo\AppData\Local\Temp\ipykernel_16700\1879636168.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   VUELTA_21team['Time'][3:] = VUELTA_21team['Time'][3:].str.replace('+', '')
# C:\Users\enzo\AppData\Local\Temp\ipykernel_16700\1879636168.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   VUELTA_21team['Time'][3:] = VUELTA_21team['Time'][3:].str.replace('+', '')
#     Pos                                Team       Time            Time.1  \
# 0     1                  Bahrain Victorious  252:19:35  10 days 12:19:35
# 1     2                         Jumbo-Visma  00: 07:26   0 days 00:07:26
# ...

# %%
VUELTA_21team['Time'] = VUELTA_21team['Time'].str.replace(' ', '')
VUELTA_21team
# Out:
#     Pos                                Team       Time            Time.1  \
# 0     1                  Bahrain Victorious  252:19:35  10 days 12:19:35
# 1     2                         Jumbo-Visma   00:07:26   0 days 00:07:26
# 2     3                    INEOS Grenadiers   00:32:18   0 days 00:32:18
# 3     4                   UAE Team Emirates   01:05:10   0 days 01:05:10
# 4     5  Intermarché-Wanty-Gobert Matériaux   01:15:05   0 days 01:15:05
# 5     6                       Movistar Team   01:17:16   0 days 01:17:16
# 6     7                   AG2R Citroën Team   01:43:04   0 days 01:43:04
# 7     8                             Cofidis   02:15:39   0 days 02:15:39
# 8     9                      Trek-Segafredo   02:38:20   0 days 02:38:20
# 9    10                            Team DSM   02:59:49   0 days 02:59:49
# 10   11                   Euskaltel-Euskadi   03:31:29   0 days 03:31:29
# 11   12                           Burgos-BH   03:49:37   0 days 03:49:37
# ...

# %%
VUELTA_21team['Time'] = pd.to_timedelta(VUELTA_21team['Time'])
VUELTA_21team.head()
# Out:
#    Pos                                Team             Time            Time.1  \
# 0    1                  Bahrain Victorious 10 days 12:19:35  10 days 12:19:35
# 1    2                         Jumbo-Visma  0 days 00:07:26   0 days 00:07:26
# 2    3                    INEOS Grenadiers  0 days 00:32:18   0 days 00:32:18
# 3    4                   UAE Team Emirates  0 days 01:05:10   0 days 01:05:10
# 4    5  Intermarché-Wanty-Gobert Matériaux  0 days 01:15:05   0 days 01:15:05
#
#    duration_mins
# 0       15139.58
# 1           7.43
# 2          32.30
# 3          65.17
# 4          75.08

# %%
VUELTA_21team['duration_mins'] = (VUELTA_21team['Time'].dt.total_seconds()/60).round(2)
VUELTA_21team.head()
# Out:
#    Pos                                Team             Time            Time.1  \
# 0    1                  Bahrain Victorious 10 days 12:19:35  10 days 12:19:35
# 1    2                         Jumbo-Visma  0 days 00:07:26   0 days 00:07:26
# 2    3                    INEOS Grenadiers  0 days 00:32:18   0 days 00:32:18
# 3    4                   UAE Team Emirates  0 days 01:05:10   0 days 01:05:10
# 4    5  Intermarché-Wanty-Gobert Matériaux  0 days 01:15:05   0 days 01:15:05
#
#    duration_mins
# 0       15139.58
# 1           7.43
# 2          32.30
# 3          65.17
# 4          75.08

# %%
# VUELTA_21team[['Time','duration_mins']].to_csv('VUELTA_21team timecleaned.csv')

# %% [markdown]
# ### VUELTA 2020

# %%
VUELTA_20 = pd.read_excel(r'D:\enzo\Documents\Data Science\Bike Prices\VUELTA 2020\2020 VUELTA.xlsx', sheet_name='GC')
VUELTA_20.head()
# Out:
#   Pos            Rider                    Team    UCI      Time
# 0   1    Roglic Primoz        Team Jumbo-Visma  850.0  72:46:12
# 1   2  Carapaz Richard        INEOS Grenadiers  680.0      + 24
# 2   3      Carthy Hugh          EF Pro Cycling  575.0   + 01:15
# 3   4    Martin Daniel  Israel Start-Up Nation  460.0   + 02:43
# 4   5        Mas Enric           Movistar Team  380.0   + 03:36

# %%
VUELTA_20['Time'][1] = VUELTA_20['Time'][1].replace('+', '00:00:')
VUELTA_20
# Out:
# C:\Users\enzo\AppData\Local\Temp\ipykernel_16700\4011815359.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   VUELTA_20['Time'][1] = VUELTA_20['Time'][1].replace('+', '00:00:')
#      Pos             Rider                    Team    UCI       Time
# 0      1     Roglic Primoz        Team Jumbo-Visma  850.0   72:46:12
# 1      2   Carapaz Richard        INEOS Grenadiers  680.0  00:00: 24
# 2      3       Carthy Hugh          EF Pro Cycling  575.0    + 01:15
# 3      4     Martin Daniel  Israel Start-Up Nation  460.0    + 02:43
# 4      5         Mas Enric           Movistar Team  380.0    + 03:36
# ..   ...               ...                     ...    ...        ...
# 171  DNF      Ligthart Pim    Total Direct Energie    NaN        NaN
# ...

# %%
VUELTA_20['Time'][2:23] = VUELTA_20['Time'][2:23].str.replace('+', '00:')
VUELTA_20.head(25)
# Out:
# C:\Users\enzo\AppData\Local\Temp\ipykernel_16700\434900842.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   VUELTA_20['Time'][2:23] = VUELTA_20['Time'][2:23].str.replace('+', '00:')
# C:\Users\enzo\AppData\Local\Temp\ipykernel_16700\434900842.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   VUELTA_20['Time'][2:23] = VUELTA_20['Time'][2:23].str.replace('+', '00:')
#    Pos                Rider                    Team    UCI        Time
# 0    1        Roglic Primoz        Team Jumbo-Visma  850.0    72:46:12
# 1    2      Carapaz Richard        INEOS Grenadiers  680.0   00:00: 24
# ...

# %%
VUELTA_20['Time'][23:] = VUELTA_20['Time'][23:].str.replace('+', '')
VUELTA_20.head(25)
# Out:
# C:\Users\enzo\AppData\Local\Temp\ipykernel_16700\3702558049.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   VUELTA_20['Time'][23:] = VUELTA_20['Time'][23:].str.replace('+', '')
# C:\Users\enzo\AppData\Local\Temp\ipykernel_16700\3702558049.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   VUELTA_20['Time'][23:] = VUELTA_20['Time'][23:].str.replace('+', '')
#    Pos                Rider                    Team    UCI       Time
# 0    1        Roglic Primoz        Team Jumbo-Visma  850.0   72:46:12
# 1    2      Carapaz Richard        INEOS Grenadiers  680.0  00:00: 24
# ...

# %%
VUELTA_20['Time'] = VUELTA_20['Time'].str.replace(' ', '')
VUELTA_20.head()
# Out:
#   Pos            Rider                    Team    UCI      Time
# 0   1    Roglic Primoz        Team Jumbo-Visma  850.0  72:46:12
# 1   2  Carapaz Richard        INEOS Grenadiers  680.0  00:00:24
# 2   3      Carthy Hugh          EF Pro Cycling  575.0  00:01:15
# 3   4    Martin Daniel  Israel Start-Up Nation  460.0  00:02:43
# 4   5        Mas Enric           Movistar Team  380.0  00:03:36

# %%
VUELTA_20['Time'] = pd.to_timedelta(VUELTA_20['Time'])
VUELTA_20
# Out:
#      Pos             Rider                    Team    UCI            Time
# 0      1     Roglic Primoz        Team Jumbo-Visma  850.0 3 days 00:46:12
# 1      2   Carapaz Richard        INEOS Grenadiers  680.0 0 days 00:00:24
# 2      3       Carthy Hugh          EF Pro Cycling  575.0 0 days 00:01:15
# 3      4     Martin Daniel  Israel Start-Up Nation  460.0 0 days 00:02:43
# 4      5         Mas Enric           Movistar Team  380.0 0 days 00:03:36
# ..   ...               ...                     ...    ...             ...
# 171  DNF      Ligthart Pim    Total Direct Energie    NaN             NaT
# 172  DNF   Elissonde Kenny          Trek-Segafredo    NaN             NaT
# 173  DNF    Kamp Alexander          Trek-Segafredo    NaN             NaT
# 174  DNF  Moschetti Matteo          Trek-Segafredo    NaN             NaT
# 175  DNF    Formolo Davide       UAE Team Emirates    NaN             NaT
#
# [176 rows x 5 columns]

# %%
VUELTA_20['Time'].loc[1:] = VUELTA_20['Time'][0] + (VUELTA_20['Time'][1:])
VUELTA_20['Time']
# Out:
# C:\Users\enzo\AppData\Local\Temp\ipykernel_16700\3155080279.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   VUELTA_20['Time'].loc[1:] = VUELTA_20['Time'][0] + (VUELTA_20['Time'][1:])
# 0     3 days 00:46:12
# 1     3 days 00:46:36
# 2     3 days 00:47:27
# 3     3 days 00:48:55
# 4     3 days 00:49:48
#             ...
# 171               NaT
# 172               NaT
# 173               NaT
# 174               NaT
# 175               NaT
# Name: Time, Length: 176, dtype: timedelta64[ns]

# %%
VUELTA_20['duration_mins'] = (VUELTA_20['Time'].dt.total_seconds()/60).round(2)
VUELTA_20.head()
# Out:
#   Pos            Rider                    Team    UCI            Time  \
# 0   1    Roglic Primoz        Team Jumbo-Visma  850.0 3 days 00:46:12
# 1   2  Carapaz Richard        INEOS Grenadiers  680.0 3 days 00:46:36
# 2   3      Carthy Hugh          EF Pro Cycling  575.0 3 days 00:47:27
# 3   4    Martin Daniel  Israel Start-Up Nation  460.0 3 days 00:48:55
# 4   5        Mas Enric           Movistar Team  380.0 3 days 00:49:48
#
#    duration_mins
# 0        4366.20
# 1        4366.60
# 2        4367.45
# 3        4368.92
# 4        4369.80

# %%
# VUELTA_20[['Time', 'duration_mins']].to_csv('VUELTA_20 timecleaned.csv')

# %%
GIRO_19 = pd.read_excel(r'D:\enzo\Documents\Data Science\Bike Prices\GIRO 2019\2019 GIRO.xlsx',sheet_name='GC')
GIRO_19.head(25)
# Out:
#    Pos                  Rider                        Team        Time     UCI
# 0   01            Bernal Egan                  Team Ineos    82:57:00  1000.0
# 1   02         Thomas Geraint                  Team Ineos     + 01:11   800.0
# 2   03      Kruijswijk Steven            Team Jumbo-Visma     + 01:31   675.0
# 3   04       Buchmann Emanuel            Bora - Hansgrohe     + 01:56   575.0
# 4   05     Alaphilippe Julian       Deceuninck-Quick Step     + 04:05   475.0
# 5   06            Landa Mikel               Movistar Team     + 04:23   400.0
# 6   07         Uran Rigoberto          EF Education First     + 05:15   325.0
# 7   08         Quintana Nairo               Movistar Team     + 05:30   275.0
# 8   09     Valverde Alejandro               Movistar Team     + 06:12   225.0
# 9   10         Barguil Warren         Team Arkéa - Samsic     + 07:32   175.0
# 10  11           Porte Richie              Trek-Segafredo     + 12:42   150.0
# ...

# %%
GIRO_19['Time'][1:22] = GIRO_19['Time'][1:22].str.replace('+', '00:')
GIRO_19
# Out:
# C:\Users\enzo\AppData\Local\Temp\ipykernel_16700\2195490854.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   GIRO_19['Time'][1:22] = GIRO_19['Time'][1:22].str.replace('+', '00:')
# C:\Users\enzo\AppData\Local\Temp\ipykernel_16700\2195490854.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   GIRO_19['Time'][1:22] = GIRO_19['Time'][1:22].str.replace('+', '00:')
#      Pos                 Rider                   Team       Time     UCI
# 0     01           Bernal Egan             Team Ineos   82:57:00  1000.0
# 1     02        Thomas Geraint             Team Ineos  00: 01:11   800.0
# ...

# %%
GIRO_19['Time'][22:] = GIRO_19['Time'][22:].str.replace('+', '')
GIRO_19.head(25)
# Out:
# C:\Users\enzo\AppData\Local\Temp\ipykernel_16700\995646689.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   GIRO_19['Time'][22:] = GIRO_19['Time'][22:].str.replace('+', '')
# C:\Users\enzo\AppData\Local\Temp\ipykernel_16700\995646689.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   GIRO_19['Time'][22:] = GIRO_19['Time'][22:].str.replace('+', '')
#    Pos                  Rider                        Team       Time     UCI
# 0   01            Bernal Egan                  Team Ineos   82:57:00  1000.0
# 1   02         Thomas Geraint                  Team Ineos  00: 01:11   800.0
# ...

# %%
GIRO_19['Time'] = GIRO_19['Time'].str.replace(' ','')
GIRO_19.head()
# Out:
#   Pos               Rider                   Team      Time     UCI
# 0  01         Bernal Egan             Team Ineos  82:57:00  1000.0
# 1  02      Thomas Geraint             Team Ineos  00:01:11   800.0
# 2  03   Kruijswijk Steven       Team Jumbo-Visma  00:01:31   675.0
# 3  04    Buchmann Emanuel       Bora - Hansgrohe  00:01:56   575.0
# 4  05  Alaphilippe Julian  Deceuninck-Quick Step  00:04:05   475.0

# %%
GIRO_19['Time'] = pd.to_timedelta(GIRO_19['Time'])
GIRO_19
# Out:
#      Pos                 Rider                   Team            Time     UCI
# 0     01           Bernal Egan             Team Ineos 3 days 10:57:00  1000.0
# 1     02        Thomas Geraint             Team Ineos 0 days 00:01:11   800.0
# 2     03     Kruijswijk Steven       Team Jumbo-Visma 0 days 00:01:31   675.0
# 3     04      Buchmann Emanuel       Bora - Hansgrohe 0 days 00:01:56   575.0
# 4     05    Alaphilippe Julian  Deceuninck-Quick Step 0 days 00:04:05   475.0
# ..   ...                   ...                    ...             ...     ...
# 171  DNF  Andersen Søren Kragh            Team Sunweb             NaT     NaN
# 172  DNF              Bol Cees            Team Sunweb             NaT     NaN
# 173  DNF       Kelderman Wilco            Team Sunweb             NaT     NaN
# 174  DNF         Terpstra Niki   Total Direct Energie             NaT     NaN
# 175  DNF      Philipsen Jasper      UAE Team Emirates             NaT     NaN
#
# [176 rows x 5 columns]

# %%
GIRO_19['Time'].loc[1:] = GIRO_19['Time'][0] + (GIRO_19['Time'][1:])
GIRO_19['Time']
# Out:
# C:\Users\enzo\AppData\Local\Temp\ipykernel_16700\4034402998.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   GIRO_19['Time'].loc[1:] = GIRO_19['Time'][0] + (GIRO_19['Time'][1:])
# 0     3 days 10:57:00
# 1     3 days 10:58:11
# 2     3 days 10:58:31
# 3     3 days 10:58:56
# 4     3 days 11:01:05
#             ...
# 171               NaT
# 172               NaT
# 173               NaT
# 174               NaT
# 175               NaT
# Name: Time, Length: 176, dtype: timedelta64[ns]

# %%
GIRO_19['duration_mins'] = (GIRO_19['Time'].dt.total_seconds()/60).round(2)
GIRO_19.head()
# Out:
#   Pos               Rider                   Team            Time     UCI  \
# 0  01         Bernal Egan             Team Ineos 3 days 10:57:00  1000.0
# 1  02      Thomas Geraint             Team Ineos 3 days 10:58:11   800.0
# 2  03   Kruijswijk Steven       Team Jumbo-Visma 3 days 10:58:31   675.0
# 3  04    Buchmann Emanuel       Bora - Hansgrohe 3 days 10:58:56   575.0
# 4  05  Alaphilippe Julian  Deceuninck-Quick Step 3 days 11:01:05   475.0
#
#    duration_mins
# 0        4977.00
# 1        4978.18
# 2        4978.52
# 3        4978.93
# 4        4981.08

# %%
# GIRO_19[['Time','duration_mins']].to_csv('GIRO_19 timecleaned.csv')

# %%
VUELTA_19 = pd.read_excel(r'D:\enzo\Documents\Data Science\Bike Prices\VUELTA 2019\2019 VUELTA.xlsx',sheet_name='GC')
VUELTA_19.head()
# Out:
#   Pos               Rider               Team      Time    UCI
# 0  01       Roglic Primoz   Team Jumbo-Visma  83:07:14  850.0
# 1  02  Valverde Alejandro      Movistar Team   + 02:33  680.0
# 2  03       Pogacar Tadej  UAE Team Emirates   + 02:55  575.0
# 3  04      Quintana Nairo      Movistar Team   + 03:46  460.0
# 4  05  López Miguel Ángel    Astana Pro Team   + 04:48  380.0

# %%
VUELTA_19['Time'][1:19] = VUELTA_19['Time'][1:19].str.replace('+', '00:')
VUELTA_19
# Out:
# C:\Users\enzo\AppData\Local\Temp\ipykernel_16700\178129524.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   VUELTA_19['Time'][1:19] = VUELTA_19['Time'][1:19].str.replace('+', '00:')
# C:\Users\enzo\AppData\Local\Temp\ipykernel_16700\178129524.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   VUELTA_19['Time'][1:19] = VUELTA_19['Time'][1:19].str.replace('+', '00:')
#      Pos               Rider               Team       Time    UCI
# 0     01       Roglic Primoz   Team Jumbo-Visma   83:07:14  850.0
# 1     02  Valverde Alejandro      Movistar Team  00: 02:33  680.0
# 2     03       Pogacar Tadej  UAE Team Emirates  00: 02:55  575.0
# ...

# %%
VUELTA_19['Time'][19:] = VUELTA_19['Time'][19:].str.replace('+', '')
VUELTA_19.head(25)
# Out:
# C:\Users\enzo\AppData\Local\Temp\ipykernel_16700\561623947.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   VUELTA_19['Time'][19:] = VUELTA_19['Time'][19:].str.replace('+', '')
# C:\Users\enzo\AppData\Local\Temp\ipykernel_16700\561623947.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   VUELTA_19['Time'][19:] = VUELTA_19['Time'][19:].str.replace('+', '')
#    Pos                Rider                        Team       Time    UCI
# 0   01        Roglic Primoz            Team Jumbo-Visma   83:07:14  850.0
# 1   02   Valverde Alejandro               Movistar Team  00: 02:33  680.0
# ...

# %%
VUELTA_19['Time'] = VUELTA_19['Time'].str.replace(' ','')
VUELTA_19.head(25)
# Out:
#    Pos                Rider                        Team      Time    UCI
# 0   01        Roglic Primoz            Team Jumbo-Visma  83:07:14  850.0
# 1   02   Valverde Alejandro               Movistar Team  00:02:33  680.0
# 2   03        Pogacar Tadej           UAE Team Emirates  00:02:55  575.0
# 3   04       Quintana Nairo               Movistar Team  00:03:46  460.0
# 4   05   López Miguel Ángel             Astana Pro Team  00:04:48  380.0
# 5   06          Majka Rafal            Bora - Hansgrohe  00:07:33  320.0
# 6   07      Kelderman Wilco                 Team Sunweb  00:10:04  260.0
# 7   08   Hagen Carl Fredrik              Lotto - Soudal  00:12:54  220.0
# 8   09           Soler Marc               Movistar Team  00:22:27  180.0
# 9   10          Nieve Mikel          Mitchelton - Scott  00:22:34  140.0
# 10  11           Knox James       Deceuninck-Quick Step  00:22:55  120.0
# 11  12          Teuns Dylan            Bahrain - Merida  00:24:06  100.0
# ...

# %%
VUELTA_19['Time'] = pd.to_timedelta(VUELTA_19['Time'])
VUELTA_19
# Out:
#      Pos               Rider               Team            Time    UCI
# 0     01       Roglic Primoz   Team Jumbo-Visma 3 days 11:07:14  850.0
# 1     02  Valverde Alejandro      Movistar Team 0 days 00:02:33  680.0
# 2     03       Pogacar Tadej  UAE Team Emirates 0 days 00:02:55  575.0
# 3     04      Quintana Nairo      Movistar Team 0 days 00:03:46  460.0
# 4     05  López Miguel Ángel    Astana Pro Team 0 days 00:04:48  380.0
# ..   ...                 ...                ...             ...    ...
# 171  DNF   Kruijswijk Steven   Team Jumbo-Visma             NaT    NaN
# 172  DNF         Martin Tony   Team Jumbo-Visma             NaT    NaN
# 173  DNF       Roche Nicolas        Team Sunweb             NaT    NaN
# 174  DNF           Aru Fabio  UAE Team Emirates             NaT    NaN
# 175  DNF       Marcato Marco  UAE Team Emirates             NaT    NaN
#
# [176 rows x 5 columns]

# %%
VUELTA_19['Time'].loc[1:] = VUELTA_19['Time'][0] + (VUELTA_19['Time'][1:])
VUELTA_19['Time']
# Out:
# C:\Users\enzo\AppData\Local\Temp\ipykernel_16700\3163647762.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   VUELTA_19['Time'].loc[1:] = VUELTA_19['Time'][0] + (VUELTA_19['Time'][1:])
# 0     3 days 11:07:14
# 1     3 days 11:09:47
# 2     3 days 11:10:09
# 3     3 days 11:11:00
# 4     3 days 11:12:02
#             ...
# 171               NaT
# 172               NaT
# 173               NaT
# 174               NaT
# 175               NaT
# Name: Time, Length: 176, dtype: timedelta64[ns]

# %%
VUELTA_19['duration_mins'] = (VUELTA_19['Time'].dt.total_seconds()/60).round(2)
VUELTA_19.head()
# Out:
#   Pos               Rider               Team            Time    UCI  \
# 0  01       Roglic Primoz   Team Jumbo-Visma 3 days 11:07:14  850.0
# 1  02  Valverde Alejandro      Movistar Team 3 days 11:09:47  680.0
# 2  03       Pogacar Tadej  UAE Team Emirates 3 days 11:10:09  575.0
# 3  04      Quintana Nairo      Movistar Team 3 days 11:11:00  460.0
# 4  05  López Miguel Ángel    Astana Pro Team 3 days 11:12:02  380.0
#
#    duration_mins
# 0        4987.23
# 1        4989.78
# 2        4990.15
# 3        4991.00
# 4        4992.03

# %%
VUELTA_19[['Time','duration_mins']].to_csv('VUELTA_19 timecleaned.csv')
